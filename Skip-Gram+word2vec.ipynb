# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like translations.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with language and words, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to covert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
from collections import Counter
import math
import random

## Your code here
threshold = 1e-5
word_counts = Counter(int_words)
total_count = len(int_words)
freqs = {word: count/total_count for word, count in word_counts.items()}
p_drop = {word: 1 - np.sqrt(threshold/freqs[word]) for word in word_counts}
train_words = [word for word in int_words if p_drop[word] < random.random()]

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    # Your code here
    R = np.random.randint(1, window_size+1)
    start = idx - R if (idx - R) > 0 else 0
    stop = idx + R
    target_words = set(words[start:idx] + words[idx+1:stop+1])
    
    return list(target_words)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From Chris McCormick's blog, we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as one-hot encoded vectors. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. This weight matrix is usually called the embedding matrix or embedding look-up table. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32,[None], name="inputs") 
    labels = tf.placeholder(tf.int32,[None,None], name="labels")

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of neurons in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using one-hot encoded vectors for our inputs. When you do the matrix multiplication of the one-hot vector with the embedding matrix, you end up selecting only one row out of the entire matrix:
#
# ![one-hot matrix multiplication](assets/matrix_mult_w_one_hot.png)
#
# You don't actually need to do the matrix multiplication, you just need to select the row in the embedding matrix that corresponds to the input word. Then, the embedding matrix becomes a lookup table, you're looking up a vector the size of the hidden layer that represents the input word.
#
# <img src="assets/word2vec_weight_matrix_lookup_table.png" width=500>
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform). This [TensorFlow tutorial](https://www.tensorflow.org/tutorials/word2vec) will help if you get stuck.

# %%
n_vocab = len(int_to_vocab)
n_embedding =  200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform([n_vocab, n_embedding],-1,1))# create embedding weight matrix here
    embed = tf.nn.embedding_lookup(embedding,inputs) # use tf.nn.embedding_lookup to get the hidden layer output

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab,n_embedding), stddev=0.1))# create softmax weight matrix here
    softmax_b = tf.Variable(tf.zeros(n_vocab))# create softmax biases here
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w,softmax_b,
                                      labels,embed,
                                      n_sampled,n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints
# Out:
# mkdir: checkpoints: File exists

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6450 0.6320 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.6410 0.6217 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.4816 0.5678 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.5742 0.5702 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.5115 0.5752 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5111 0.5898 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5575 0.5699 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5578 0.5672 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4620 0.5044 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4090 0.3482 sec/batch
# Nearest to have: subsidies, monolithic, peripatetic, geometry, rts, untouched, bard, dbu,
# Nearest to between: subdominant, homage, differed, boudin, biblioth, bmod, trance, element,
# Nearest to were: daemen, shalom, though, misalignment, oersted, motorcycle, cops, nontrinitarian,
# Nearest to this: mamas, iridescent, enthusiasms, bafta, fullerton, appendant, eggs, insignificant,
# Nearest to so: verant, appalled, ndp, narrator, tessa, marqu, dubai, musket,
# Nearest to but: ventilation, pujol, ceasing, pegging, degeneration, jscript, croft, due,
# Nearest to i: benzene, chile, wads, psionic, pottery, enumeration, stevie, spliced,
# Nearest to th: napol, rowan, miskelley, ceawlin, margret, felling, botanical, virginia,
# Nearest to woman: naci, guess, wetlands, frigg, patients, masse, breuer, oddities,
# Nearest to engineering: hestia, mycobacterium, samplers, sahib, potok, shusui, speeded, lass,
# Nearest to dr: uncensored, fairness, stark, tabari, contemporaneous, everson, treachery, ese,
# Nearest to issue: lobster, saints, jumaada, bigg, ligature, variance, guzm, heist,
# Nearest to egypt: perspective, calculates, beds, asterix, ticket, providential, annales, choate,
# Nearest to gold: rpgs, epitomised, suppresses, estimators, specifier, loom, sheng, lads,
# Nearest to pressure: remonstrance, traumatized, univision, halachic, roz, acta, radioisotopes, eichmann,
# Nearest to something: disembarked, balla, narrowest, he, tursiops, rhenium, http, afar,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.4430 0.3532 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.3856 0.3473 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3159 0.3471 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2221 0.3453 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.1632 0.3457 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1139 0.3499 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.1183 0.3466 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0483 0.3808 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 4.9827 0.3474 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.9585 0.3471 sec/batch
# Nearest to have: subsidies, geometry, enable, peripatetic, pull, mosquito, subordinated, poplar,
# Nearest to between: subdominant, homage, differed, element, wasn, troubles, trance, machinery,
# Nearest to were: though, daemen, shalom, nontrinitarian, in, city, motorcycle, establishes,
# Nearest to this: mamas, eggs, iridescent, enthusiasms, bafta, received, propagated, transitivity,
# Nearest to so: appears, ndp, narrator, fifth, debt, marrying, accepts, tessa,
# Nearest to but: ventilation, due, revealed, ceasing, pujol, croft, george, degeneration,
# Nearest to i: benzene, chile, pottery, rites, enumeration, asking, molecular, wads,
# Nearest to th: miskelley, virginia, napol, rowan, reflect, ceawlin, voluntary, nell,
# Nearest to woman: patients, guess, naci, wetlands, breuer, frigg, certificates, rated,
# Nearest to engineering: hestia, unwillingly, shusui, speeded, numerator, pushes, mycobacterium, dwelling,
# Nearest to dr: everson, treachery, uncensored, fairness, varanasi, stark, excessively, glengarry,
# Nearest to issue: saints, variance, tensions, guzm, lobster, database, ndor, governs,
# Nearest to egypt: perspective, beds, calculates, ticket, asterix, annales, schema, bonneville,
# Nearest to gold: rpgs, suppresses, epitomised, used, estimators, specifier, sheng, loom,
# Nearest to pressure: remonstrance, individual, mercy, backpack, eichmann, psychosocial, tit, rhythmic,
# Nearest to something: he, disembarked, http, master, balla, particular, narrowest, reach,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9381 0.3659 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.8949 0.3555 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8834 0.3466 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8561 0.3497 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8189 0.3459 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8031 0.3471 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.8132 0.3460 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.7882 0.3460 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7788 0.3485 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7762 0.3481 sec/batch
# Nearest to have: subsidies, geometry, monolithic, pull, enable, mosquito, quantities, scan,
# Nearest to between: subdominant, homage, differed, element, trance, propounded, wasn, decline,
# Nearest to were: though, daemen, shalom, establishes, nontrinitarian, oersted, in, motorcycle,
# Nearest to this: mamas, eggs, enthusiasms, bafta, iridescent, insignificant, propagated, diana,
# Nearest to so: appalled, suspension, ndp, appears, narrator, debt, verant, deacons,
# Nearest to but: ventilation, ceasing, revealed, pujol, lifeforms, transcribed, degeneration, croft,
# Nearest to i: benzene, chile, asking, submit, wads, officio, insurance, distinguishable,
# Nearest to th: napol, rowan, miskelley, virginia, partly, margret, nell, botanical,
# Nearest to woman: guess, wetlands, patients, frigg, breuer, naci, struggled, oddities,
# Nearest to engineering: hestia, neighbours, lass, speeded, dwelling, peerage, motions, shusui,
# Nearest to dr: stark, everson, uncensored, fairness, treachery, contemporaneous, guarded, excessively,
# Nearest to issue: saints, tensions, guzm, governs, heist, variance, lobster, ligature,
# Nearest to egypt: calculates, perspective, beds, ticket, annales, asterix, schema, programmatic,
# Nearest to gold: rpgs, suppresses, epitomised, unbroken, estimators, specifier, loom, used,
# Nearest to pressure: remonstrance, individual, tit, emptied, radioisotopes, eichmann, mercy, acta,
# Nearest to something: he, disembarked, merits, oz, narrowest, http, insanity, master,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7554 0.3516 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7414 0.3599 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7290 0.3490 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.6918 0.3457 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7535 0.3571 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.6767 0.3704 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.6807 0.3555 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7607 0.3509 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.7211 0.3490 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6395 0.3455 sec/batch
# Nearest to have: subsidies, monolithic, pull, untouched, mosquito, geometry, scan, quantities,
# Nearest to between: subdominant, homage, differed, trance, element, livonia, propounded, troubles,
# Nearest to were: daemen, though, establishes, in, oersted, shalom, nontrinitarian, motorcycle,
# Nearest to this: mamas, eggs, iridescent, enthusiasms, bafta, insignificant, diana, propagated,
# Nearest to so: appalled, suspension, verant, sanctification, elaborates, appears, randi, narrator,
# Nearest to but: ventilation, ceasing, lifeforms, pegging, pujol, transcribed, kingdoms, degeneration,
# Nearest to i: benzene, spliced, wads, chile, asking, affiliation, distinguishable, submit,
# Nearest to th: napol, rowan, margret, virginia, kurds, miskelley, felling, nell,
# Nearest to woman: guess, frigg, breuer, masse, naci, patients, certificates, wetlands,
# Nearest to engineering: hestia, shusui, motions, neighbours, numerator, speeded, lass, potok,
# Nearest to dr: uncensored, stark, everson, contemporaneous, fairness, guarded, treachery, excessively,
# Nearest to issue: saints, tensions, governs, baghdad, guzm, lobster, heist, ligature,
# Nearest to egypt: calculates, perspective, ticket, beds, annales, platonist, asterix, schema,
# Nearest to gold: rpgs, suppresses, epitomised, estimators, unbroken, loom, specifier, goddamn,
# Nearest to pressure: remonstrance, univision, visionaries, individual, halachic, acta, scrape, tit,
# Nearest to something: disembarked, merits, he, narrowest, versed, balla, insanity, oz,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6822 0.3510 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6617 0.3473 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6311 0.3459 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6604 108.4038 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6329 211.2364 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6370 0.4332 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.5904 0.2893 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5394 0.3994 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5146 0.4442 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.4967 0.4339 sec/batch
# Nearest to have: subsidies, pull, monolithic, untouched, acquiesce, scan, needham, bard,
# Nearest to between: subdominant, differed, homage, trance, propounded, livonia, lakeshore, pericles,
# Nearest to were: daemen, though, in, oersted, establishes, shalom, nontrinitarian, scrub,
# Nearest to this: mamas, enthusiasms, eggs, bafta, iridescent, insignificant, fullerton, diana,
# Nearest to so: appalled, interludes, sanctification, appears, verant, elaborates, ndp, reasoned,
# Nearest to but: ventilation, lifeforms, ceasing, pujol, pegging, transcribed, removing, revealed,
# Nearest to i: benzene, wads, spliced, chile, asking, stevie, affiliation, nurses,
# Nearest to th: napol, rowan, margret, virginia, felling, miskelley, kurds, ennio,
# Nearest to woman: guess, frigg, breuer, masse, naci, certificates, migrant, patients,
# Nearest to engineering: shusui, hestia, neighbours, motions, speeded, mycobacterium, numerator, samplers,
# Nearest to dr: everson, uncensored, stark, inventor, contemporaneous, conductor, herbert, published,
# Nearest to issue: governs, saints, tensions, heist, lobster, baghdad, ssy, inspire,
# Nearest to egypt: calculates, perspective, ticket, annales, beds, platonist, asterix, banquet,
# Nearest to gold: rpgs, suppresses, epitomised, estimators, loom, unbroken, specifier, goddamn,
# Nearest to pressure: remonstrance, univision, halachic, visionaries, traumatized, psychosocial, tit, scrape,
# Nearest to something: narrowest, merits, disembarked, he, balla, insanity, arrogant, helps,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.5175 0.4156 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.5054 0.3849 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4541 0.3492 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5442 0.3424 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.4984 0.3486 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4555 0.3447 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4754 0.3485 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.4082 0.3755 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4165 0.3894 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4447 0.3512 sec/batch
# Nearest to have: subsidies, pull, monolithic, prefrontal, mosquito, enable, programmatic, untouched,
# Nearest to between: subdominant, differed, trance, homage, livonia, element, propounded, wherein,
# Nearest to were: daemen, though, in, oersted, establishes, scrub, nontrinitarian, styx,
# Nearest to this: mamas, enthusiasms, fullerton, propagated, mtsho, eggs, reformatory, backgrounds,
# Nearest to so: appalled, interludes, appears, verant, sanctification, suspension, flowchart, reasoned,
# Nearest to but: lifeforms, ventilation, pegging, ceasing, kingdoms, removing, pujol, communally,
# Nearest to i: benzene, wads, spliced, asking, blackboard, stevie, ryle, lighten,
# Nearest to th: napol, rowan, margret, felling, tidings, kurds, virginia, miskelley,
# Nearest to woman: frigg, breuer, guess, certificates, migrant, masse, naci, citigroup,
# Nearest to engineering: shusui, motions, speeded, hestia, neighbours, lifes, unwillingly, mycobacterium,
# Nearest to dr: everson, uncensored, stark, contemporaneous, published, tabari, treachery, barons,
# Nearest to issue: tensions, governs, saints, heist, baghdad, criminalization, lobster, ssy,
# Nearest to egypt: calculates, annales, ticket, perspective, beds, platonist, banknotes, colonies,
# Nearest to gold: rpgs, suppresses, epitomised, estimators, specifier, nazionale, nlm, loom,
# Nearest to pressure: univision, remonstrance, halachic, damaging, tit, psychosocial, fluids, scrape,
# Nearest to something: merits, he, disembarked, narrowest, master, balla, arrogant, insanity,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.3994 0.3925 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4203 0.3686 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4322 0.3603 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.3961 0.3777 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.4156 0.3625 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4683 0.3827 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3859 0.3569 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3812 0.4100 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4159 0.4338 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3599 0.4496 sec/batch
# Nearest to have: subsidies, prefrontal, monolithic, pull, dbu, lobbied, mosquito, needham,
# Nearest to between: subdominant, differed, livonia, lakeshore, trance, rotates, propounded, element,
# Nearest to were: daemen, though, in, oersted, scrub, establishes, nontrinitarian, shahada,
# Nearest to this: enthusiasms, mamas, ast, fullerton, reformatory, endian, diana, backgrounds,
# Nearest to so: appalled, interludes, appears, suspension, sanctification, reasoned, verant, elaborates,
# Nearest to but: lifeforms, ventilation, communally, pegging, pujol, kingdoms, removing, ceasing,
# Nearest to i: benzene, spliced, wads, asking, lighten, ryle, blackboard, nurses,
# Nearest to th: napol, rowan, tidings, margret, americanization, miskelley, derives, kurds,
# Nearest to woman: breuer, guess, frigg, certificates, masse, migrant, grandfather, oddities,
# Nearest to engineering: shusui, speeded, motions, lifes, unwillingly, neighbours, samplers, stwertka,
# Nearest to dr: everson, uncensored, published, stark, contemporaneous, tabari, barons, herbert,
# Nearest to issue: governs, tensions, saints, chiefly, baghdad, criminalization, unhelpful, heist,
# Nearest to egypt: annales, calculates, ticket, platonist, slither, perspective, asterix, montserrat,
# Nearest to gold: suppresses, rpgs, silver, specifier, estimators, epitomised, nazionale, fingerings,
# Nearest to pressure: univision, remonstrance, damaging, fluids, tit, scrape, halachic, insulating,
# Nearest to something: he, merits, disembarked, insanity, master, unknowingly, arrogant, narrowest,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3764 0.4022 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.3871 0.3716 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3726 9.3064 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3519 9.5069 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.4012 18.4289 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3719 5.5025 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.4125 0.4260 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3790 0.3940 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3274 0.3408 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3363 0.3328 sec/batch
# Nearest to have: subsidies, dbu, prefrontal, monolithic, lies, mosquito, enable, pull,
# Nearest to between: subdominant, differed, rotates, lakeshore, livonia, trance, propounded, mudslides,
# Nearest to were: daemen, in, though, oersted, scrub, establishes, shahada, reluctantly,
# Nearest to this: mamas, enthusiasms, ast, fullerton, internally, reformatory, endian, propagated,
# Nearest to so: appalled, interludes, suspension, elaborates, verant, appears, sanctification, phobias,
# Nearest to but: lifeforms, ventilation, degeneration, communally, pegging, kingdoms, removing, pujol,
# Nearest to i: spliced, benzene, wads, asking, ryle, nurses, blackboard, axiomatization,
# Nearest to th: napol, rowan, derives, heroic, kurds, margret, handwriting, tidings,
# Nearest to woman: breuer, frigg, guess, certificates, masse, grandfather, oddities, freeport,
# Nearest to engineering: shusui, speeded, motions, lifes, samplers, unwillingly, neighbours, stwertka,
# Nearest to dr: uncensored, everson, stark, published, delle, barons, tabari, contemporaneous,
# Nearest to issue: governs, tensions, chiefly, unhelpful, baghdad, saints, criminalization, heist,
# Nearest to egypt: annales, calculates, platonist, slither, perspective, ticket, colonies, episcopalians,
# Nearest to gold: silver, suppresses, rpgs, specifier, nazionale, estimators, epitomised, fingerings,
# Nearest to pressure: remonstrance, scrape, univision, damaging, halachic, tit, insulating, drainage,
# Nearest to something: he, disembarked, merits, insanity, arrogant, master, potok, unknowingly,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3533 0.3409 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.2860 0.3357 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3981 0.3360 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3769 0.3584 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3939 0.3806 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.3141 0.3512 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.3071 0.3533 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3327 0.3503 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2103 0.3655 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.3092 0.3442 sec/batch
# Nearest to have: subsidies, prefrontal, knowledgeable, yolande, dbu, imparting, closeness, heater,
# Nearest to between: subdominant, rotates, lakeshore, differed, livonia, propounded, mudslides, trance,
# Nearest to were: daemen, in, oersted, though, scrub, sparta, establishes, embellishments,
# Nearest to this: enthusiasms, mamas, fullerton, reformatory, ast, appendant, taxa, endian,
# Nearest to so: appalled, interludes, elaborates, appears, verant, sanctification, suspension, mightily,
# Nearest to but: ventilation, communally, lifeforms, degeneration, pegging, removing, kingdoms, digraph,
# Nearest to i: wads, spliced, benzene, asking, ryle, blackboard, alphonsus, lighten,
# Nearest to th: napol, rowan, derives, margret, kurds, tidings, americanization, heroic,
# Nearest to woman: breuer, guess, frigg, female, migrant, fertility, birth, masse,
# Nearest to engineering: shusui, lifes, speeded, motions, samplers, unwillingly, coffea, stwertka,
# Nearest to dr: uncensored, everson, stark, delle, barons, published, walker, tabari,
# Nearest to issue: governs, tensions, saints, chiefly, unhelpful, irked, ssy, heist,
# Nearest to egypt: annales, calculates, platonist, slither, perspective, ca, episcopalians, ticket,
# Nearest to gold: silver, suppresses, specifier, rpgs, nazionale, estimators, epitomised, fingerings,
# Nearest to pressure: scrape, halachic, drainage, remonstrance, univision, tit, megaton, locative,
# Nearest to something: he, disembarked, merits, insanity, arrogant, master, potok, versed,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.3122 0.3415 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.3029 0.3556 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3088 0.1783 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2585 0.3995 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2288 0.4363 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2186 0.3793 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2321 0.4028 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.2007 0.3656 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2217 0.3607 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.2001 0.3965 sec/batch
# Nearest to have: subsidies, dbu, prefrontal, closeness, preslav, untouched, khoikhoi, enhances,
# Nearest to between: subdominant, rotates, propounded, lakeshore, differed, livonia, homage, pericles,
# Nearest to were: sparta, daemen, in, though, oersted, scrub, razed, shahada,
# Nearest to this: enthusiasms, fullerton, mamas, ast, reformatory, appendant, endian, taxa,
# Nearest to so: appalled, verant, appears, interludes, phobias, elaborates, reasoned, mightily,
# Nearest to but: communally, lifeforms, ventilation, kingdoms, removing, degeneration, pegging, unep,
# Nearest to i: wads, ryle, spliced, benzene, asking, blackboard, alphonsus, lighten,
# Nearest to th: napol, derives, tidings, margret, cursive, reflect, kurds, handwriting,
# Nearest to woman: breuer, guess, frigg, birth, female, fertility, migrant, certificates,
# Nearest to engineering: shusui, lifes, speeded, unwillingly, samplers, motions, coffea, tombigbee,
# Nearest to dr: uncensored, everson, stark, delle, barons, jordi, merrill, tabari,
# Nearest to issue: governs, tensions, unhelpful, irked, criminalization, heist, saints, ssy,
# Nearest to egypt: annales, platonist, slither, calculates, ca, perspective, episcopalians, banquet,
# Nearest to gold: silver, nazionale, suppresses, specifier, rpgs, estimators, fingerings, annually,
# Nearest to pressure: scrape, tit, remonstrance, drainage, damaging, halachic, locative, megaton,
# Nearest to something: he, disembarked, merits, arrogant, insanity, unknowingly, master, adventure,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2424 0.3932 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.1940 0.3598 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2400 0.3537 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1344 0.3654 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1677 0.3873 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1766 0.3778 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1834 0.4022 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1594 0.4077 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.2046 0.4470 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1666 0.3799 sec/batch
# Nearest to have: subsidies, prefrontal, enhances, closeness, dbu, mosquito, whois, knowledgeable,
# Nearest to between: subdominant, rotates, lakeshore, wherein, numbers, livonia, propounded, easterners,
# Nearest to were: sparta, daemen, scrub, embellishments, styx, catered, misalignment, razed,
# Nearest to this: enthusiasms, mamas, ast, fullerton, reformatory, endian, appendant, taxa,
# Nearest to so: appalled, interludes, verant, elaborates, mightily, phobias, suspension, appears,
# Nearest to but: communally, removing, ventilation, ceasing, degeneration, jscript, lifeforms, pegging,
# Nearest to i: wads, blackboard, ryle, spliced, asking, benzene, sine, axiomatization,
# Nearest to th: napol, derives, create, colonizing, reflect, cursive, tidings, handwriting,
# Nearest to woman: breuer, guess, fertility, birth, frigg, female, migrant, tootsie,
# Nearest to engineering: lifes, shusui, coffea, unwillingly, speeded, tombigbee, samplers, net,
# Nearest to dr: uncensored, everson, stark, delle, barons, adaptation, merrill, maggie,
# Nearest to issue: governs, tensions, unhelpful, criminalization, irked, heist, chiefly, thummim,
# Nearest to egypt: annales, ca, slither, calculates, platonist, episcopalians, gallico, bonneville,
# Nearest to gold: silver, specifier, nazionale, rpgs, suppresses, estimators, buffalo, annually,
# Nearest to pressure: scrape, damaging, megaton, halachic, drainage, insulating, tit, locative,
# Nearest to something: he, disembarked, merits, arrogant, insanity, unknowingly, adventure, down,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1376 0.3603 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2184 0.3578 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1595 0.3612 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1819 0.3541 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.2022 0.3546 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1889 0.3607 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.2094 0.3753 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1397 0.3457 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1626 0.3449 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1970 0.3427 sec/batch
# Nearest to have: subsidies, prefrontal, whois, lies, closeness, enhances, proportionally, amerindian,
# Nearest to between: subdominant, rotates, lakeshore, propounded, numbers, nordic, livonia, spacewalks,
# Nearest to were: daemen, sparta, embellishments, misalignment, oersted, catered, though, scrub,
# Nearest to this: enthusiasms, mamas, ast, reformatory, fullerton, appendant, taxa, endian,
# Nearest to so: appalled, interludes, phobias, verant, elaborates, suspension, reasoned, mightily,
# Nearest to but: communally, ventilation, removing, degeneration, lifeforms, ceasing, jscript, digraph,
# Nearest to i: blackboard, wads, ryle, spliced, asking, benzene, lighten, axiomatization,
# Nearest to th: napol, derives, cursive, handwriting, rd, create, colonizing, margret,
# Nearest to woman: fertility, female, breuer, frigg, birth, migrant, guess, live,
# Nearest to engineering: coffea, shusui, unwillingly, speeded, lifes, development, samplers, tombigbee,
# Nearest to dr: uncensored, everson, delle, barons, adaptation, stark, corrosive, tabari,
# Nearest to issue: governs, unhelpful, tensions, irked, heist, chiefly, criminalization, darth,
# Nearest to egypt: annales, ca, slither, platonist, calculates, asterix, gallico, bonneville,
# Nearest to gold: silver, nazionale, estimators, specifier, suppresses, annually, buffalo, rpgs,
# Nearest to pressure: scrape, remonstrance, megaton, damaging, halachic, univision, tit, locative,
# Nearest to something: he, merits, disembarked, arrogant, insanity, unknowingly, oz, potok,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.2055 0.3419 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1708 0.3397 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1910 0.3368 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1968 0.3377 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1618 0.3382 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1226 0.3342 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1573 0.3377 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1086 0.3398 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.1949 0.3455 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.2143 0.3511 sec/batch
# Nearest to have: subsidies, lies, prefrontal, untouched, closeness, whois, proportionally, yolande,
# Nearest to between: subdominant, rotates, livonia, lakeshore, nordic, tanganyika, mudslides, easterners,
# Nearest to were: daemen, sparta, in, catered, reluctantly, frustrated, azeris, though,
# Nearest to this: enthusiasms, mamas, fullerton, ast, reformatory, appendant, taxa, ceremonial,
# Nearest to so: appalled, interludes, verant, elaborates, phobias, mightily, queen, suspension,
# Nearest to but: communally, kingdoms, removing, ceasing, ventilation, pegging, lifeforms, wielded,
# Nearest to i: wads, blackboard, ryle, asking, spliced, benzene, furtherance, deformations,
# Nearest to th: napol, rd, derives, colonizing, margret, create, handwriting, cursive,
# Nearest to woman: fertility, female, breuer, birth, migrant, frigg, guess, tootsie,
# Nearest to engineering: coffea, shusui, speeded, unwillingly, samplers, lifes, partitas, development,
# Nearest to dr: uncensored, delle, everson, barons, merrill, tabari, stark, published,
# Nearest to issue: governs, unhelpful, irked, tensions, chiefly, kampuchean, heist, darth,
# Nearest to egypt: ca, annales, platonist, slither, calculates, bonneville, gallico, dubai,
# Nearest to gold: silver, nazionale, estimators, buffalo, specifier, suppresses, annually, rpgs,
# Nearest to pressure: scrape, remonstrance, megaton, damaging, tit, locative, halachic, ukrainians,
# Nearest to something: disembarked, he, merits, arrogant, insanity, potok, unknowingly, down,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2669 0.3630 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1509 0.3488 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1521 0.3438 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1610 0.3382 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0228 0.3412 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1538 0.3695 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1503 0.3394 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1421 0.3413 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1963 0.0759 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.0947 0.3404 sec/batch
# Nearest to have: subsidies, whois, lies, difficult, untouched, prefrontal, closeness, enhances,
# Nearest to between: subdominant, rotates, livonia, lakeshore, nordic, numbers, respectively, trance,
# Nearest to were: daemen, counterbalanced, catered, misalignment, in, sparta, frustrated, oersted,
# Nearest to this: enthusiasms, fullerton, mamas, ast, appendant, reformatory, taxa, exactly,
# Nearest to so: appalled, elaborates, verant, interludes, phobias, barman, reasoned, queen,
# Nearest to but: communally, removing, ventilation, jscript, lifeforms, degeneration, digraph, ceasing,
# Nearest to i: wads, blackboard, ryle, asking, deformations, sine, spliced, benzene,
# Nearest to th: rd, napol, colonizing, derives, margret, create, handwriting, reflect,
# Nearest to woman: fertility, female, breuer, migrant, birth, frigg, guess, adult,
# Nearest to engineering: coffea, shusui, samplers, speeded, unwillingly, tombigbee, lifes, graduated,
# Nearest to dr: uncensored, delle, everson, merrill, barons, abuses, stark, tabari,
# Nearest to issue: governs, unhelpful, irked, tensions, kampuchean, subroutines, heist, criminalization,
# Nearest to egypt: ca, annales, calculates, platonist, slither, puritanism, egyptians, bonneville,
# Nearest to gold: silver, nazionale, estimators, specifier, suppresses, rpgs, buffalo, mined,
# Nearest to pressure: scrape, remonstrance, megaton, damaging, locative, tit, halachic, drainage,
# Nearest to something: he, disembarked, merits, arrogant, insanity, oz, potok, unknowingly,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0815 0.3475 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0766 0.3431 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.1040 0.3415 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0654 0.3429 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.1072 0.3422 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0330 0.3428 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.0976 0.3500 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.0921 0.3396 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1228 0.3497 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0494 0.3426 sec/batch
# Nearest to have: subsidies, prefrontal, whois, amerindian, communicate, living, untouched, lies,
# Nearest to between: subdominant, rotates, livonia, trance, lakeshore, wherein, easterners, propounded,
# Nearest to were: catered, sparta, daemen, in, misalignment, counterbalanced, chicanos, pathologists,
# Nearest to this: enthusiasms, mamas, ast, appendant, exactly, fullerton, reformatory, motherboard,
# Nearest to so: appalled, verant, interludes, queen, elaborates, phobias, barman, mightily,
# Nearest to but: communally, removing, jscript, lifeforms, ventilation, kingdoms, efficient, degeneration,
# Nearest to i: wads, blackboard, asking, ryle, rulership, deformations, hath, spliced,
# Nearest to th: rd, colonizing, napol, create, margret, reflect, handwriting, derives,
# Nearest to woman: fertility, female, migrant, breuer, birth, frigg, guess, adult,
# Nearest to engineering: shusui, coffea, samplers, unwillingly, speeded, graduated, tombigbee, arrears,
# Nearest to dr: uncensored, delle, everson, merrill, barons, abuses, jordi, molitor,
# Nearest to issue: governs, irked, unhelpful, tensions, criminalization, kampuchean, subroutines, heist,
# Nearest to egypt: ca, platonist, calculates, annales, egyptians, slither, puritanism, bonneville,
# Nearest to gold: silver, nazionale, estimators, specifier, rpgs, suppresses, buffalo, annually,
# Nearest to pressure: megaton, scrape, remonstrance, damaging, tit, univision, locative, halachic,
# Nearest to something: he, disembarked, merits, arrogant, oz, insanity, unknowingly, eyewitnesses,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0294 0.3454 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0367 0.3647 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 4.0321 0.3376 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0586 0.3371 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0958 0.3376 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0580 0.3372 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0741 0.3366 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.1013 0.3376 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0522 0.3388 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0484 0.3365 sec/batch
# Nearest to have: prefrontal, subsidies, whois, closeness, amerindian, lies, living, encyclopedic,
# Nearest to between: subdominant, rotates, nordic, wherein, numbers, respectively, livonia, amigaone,
# Nearest to were: sparta, catered, misalignment, daemen, chicanos, frustrated, in, counterbalanced,
# Nearest to this: enthusiasms, ast, mamas, appendant, exactly, taxa, reformatory, mainframe,
# Nearest to so: appalled, phobias, verant, elaborates, interludes, reasoned, suspension, reschedule,
# Nearest to but: communally, removing, jscript, divisional, time, negation, ceylon, bankrupt,
# Nearest to i: blackboard, wads, sine, ryle, asking, deformations, spliced, lighten,
# Nearest to th: rd, colonizing, napol, handwriting, margret, create, reflect, cursive,
# Nearest to woman: fertility, female, breuer, migrant, guess, adult, birth, frigg,
# Nearest to engineering: coffea, universities, shusui, graduated, tombigbee, samplers, development, manufacturing,
# Nearest to dr: uncensored, delle, barons, merrill, everson, adaptation, molitor, straightforwardly,
# Nearest to issue: governs, unhelpful, irked, tensions, kampuchean, criminalization, heist, darth,
# Nearest to egypt: calculates, ca, egyptians, slither, annales, platonist, bonneville, dubai,
# Nearest to gold: silver, nazionale, estimators, specifier, rpgs, fingerings, annually, buffalo,
# Nearest to pressure: scrape, megaton, damaging, remonstrance, insulating, locative, univision, tit,
# Nearest to something: he, disembarked, merits, arrogant, potok, oz, eyewitnesses, unknowingly,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0572 0.3433 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0804 0.3403 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.1021 0.3413 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0508 0.3636 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0917 0.3571 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0423 0.3436 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0810 0.3381 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0615 0.3403 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0869 0.3379 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0913 0.3383 sec/batch
# Nearest to have: subsidies, prefrontal, amerindian, closeness, whois, untouched, proportionally, mennonite,
# Nearest to between: subdominant, rotates, nordic, lakeshore, trance, amigaone, respectively, ngc,
# Nearest to were: in, catered, had, sparta, daemen, frustrated, misalignment, chicanos,
# Nearest to this: enthusiasms, ast, appendant, mamas, semitic, mainframe, exactly, moorland,
# Nearest to so: appalled, phobias, verant, elaborates, interludes, safeguard, barman, queen,
# Nearest to but: communally, jscript, ceylon, removing, bankrupt, degeneration, ghazni, efficient,
# Nearest to i: wads, blackboard, asking, rulership, ryle, lighten, spliced, alphonsus,
# Nearest to th: rd, colonizing, handwriting, create, napol, heroic, margret, reflect,
# Nearest to woman: fertility, female, breuer, frigg, adult, migrant, birth, guess,
# Nearest to engineering: coffea, graduated, shusui, universities, tombigbee, samplers, partitas, universitet,
# Nearest to dr: uncensored, delle, barons, adaptation, abuses, everson, merrill, straightforwardly,
# Nearest to issue: governs, unhelpful, irked, chiefly, heist, initiations, kampuchean, darth,
# Nearest to egypt: calculates, ca, egyptians, slither, annales, puritanism, platonist, bonneville,
# Nearest to gold: silver, nazionale, estimators, specifier, rpgs, mined, annually, buffalo,
# Nearest to pressure: scrape, megaton, remonstrance, damaging, tit, eichmann, insulating, locative,
# Nearest to something: disembarked, arrogant, merits, potok, he, eyewitnesses, oz, unknowingly,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0480 0.3453 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 4.0148 0.3393 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0454 0.3387 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0856 0.3405 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0810 0.3475 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1252 0.3939 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1384 0.3623 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0585 0.3757 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0493 0.4508 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0459 0.3716 sec/batch
# Nearest to have: closeness, amerindian, prefrontal, subsidies, proportionally, whois, bia, mennonite,
# Nearest to between: subdominant, rotates, trance, nordic, respectively, wherein, lakeshore, keplerian,
# Nearest to were: catered, misalignment, frustrated, counterbalanced, daemen, chicanos, sparta, though,
# Nearest to this: enthusiasms, mamas, appendant, ast, fullerton, exactly, mainframe, moorland,
# Nearest to so: appalled, barman, elaborates, interludes, phobias, queen, verant, reschedule,
# Nearest to but: communally, removing, ceylon, jscript, efficient, ghazni, bankrupt, wielded,
# Nearest to i: wads, blackboard, asking, benzene, wouldn, deformations, rulership, sine,
# Nearest to th: rd, margret, colonizing, napol, handwriting, heroic, create, reflect,
# Nearest to woman: fertility, female, breuer, migrant, adult, frigg, birth, guess,
# Nearest to engineering: coffea, shusui, graduated, universitet, samplers, tombigbee, universities, partitas,
# Nearest to dr: uncensored, barons, delle, abuses, adaptation, merrill, jordi, findings,
# Nearest to issue: governs, unhelpful, irked, initiations, heist, tensions, kampuchean, chiefly,
# Nearest to egypt: calculates, ca, egyptians, annales, slither, bonneville, puritanism, dubai,
# Nearest to gold: silver, specifier, nazionale, estimators, rpgs, annually, mined, kneel,
# Nearest to pressure: scrape, megaton, remonstrance, damaging, eichmann, exhaust, tit, senegalese,
# Nearest to something: disembarked, arrogant, merits, potok, eyewitnesses, insanity, oz, ve,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9632 0.3774 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0193 0.3577 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0403 0.3939 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0330 0.3813 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0867 0.3617 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0277 0.3485 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 4.0101 0.3707 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9746 0.3699 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.0240 0.3688 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9904 0.3748 sec/batch
# Nearest to have: closeness, amerindian, subsidies, whois, proportionally, prefrontal, preslav, communicate,
# Nearest to between: subdominant, rotates, trance, wherein, nordic, lakeshore, ngc, livonia,
# Nearest to were: catered, misalignment, counterbalanced, chicanos, frustrated, daemen, lamar, razed,
# Nearest to this: enthusiasms, ast, appendant, the, moorland, mainframe, exactly, fullerton,
# Nearest to so: appalled, elaborates, verant, interludes, phobias, barman, reasoned, reschedule,
# Nearest to but: communally, ghazni, ceylon, removing, wielded, jscript, efficient, zoroastrians,
# Nearest to i: wads, blackboard, rulership, asking, wouldn, deformations, benzene, hath,
# Nearest to th: rd, colonizing, margret, create, handwriting, napol, reflect, cursive,
# Nearest to woman: fertility, female, breuer, adult, frigg, nurse, guess, migrant,
# Nearest to engineering: shusui, coffea, manufacturing, tombigbee, universitet, graduated, speeded, samplers,
# Nearest to dr: uncensored, barons, abuses, delle, adaptation, merrill, everson, jordi,
# Nearest to issue: governs, unhelpful, irked, kampuchean, heist, subroutines, initiations, tensions,
# Nearest to egypt: egyptians, ca, calculates, annales, puritanism, slither, platonist, bonneville,
# Nearest to gold: silver, nazionale, estimators, specifier, rpgs, kneel, mined, fingerings,
# Nearest to pressure: scrape, megaton, remonstrance, exhaust, senegalese, damaging, insulating, univision,
# Nearest to something: disembarked, arrogant, merits, potok, eyewitnesses, he, oz, ve,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 3.9779 0.3837 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9303 0.3791 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 4.0244 0.3664 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0024 0.3785 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.0100 0.3822 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 4.0005 0.3795 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.9302 0.4320 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9376 0.4010 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9186 0.3737 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9938 0.3614 sec/batch
# Nearest to have: closeness, subsidies, prefrontal, amerindian, otariidae, whois, developing, proportionally,
# Nearest to between: subdominant, rotates, wherein, trance, nordic, lakeshore, respectively, keplerian,
# Nearest to were: catered, misalignment, chicanos, counterbalanced, razed, lamar, had, frustrated,
# Nearest to this: ast, exactly, in, enthusiasms, moorland, appendant, the, mamas,
# Nearest to so: appalled, barman, elaborates, verant, phobias, interludes, my, queen,
# Nearest to but: communally, removing, time, efficient, jscript, quits, ceylon, bankrupt,
# Nearest to i: wads, blackboard, deformations, wouldn, asking, rulership, know, kings,
# Nearest to th: rd, colonizing, create, handwriting, reflect, margret, cursive, paced,
# Nearest to woman: fertility, female, adult, nurse, guess, breuer, frigg, migrant,
# Nearest to engineering: shusui, universitet, manufacturing, coffea, tombigbee, graduated, universities, tech,
# Nearest to dr: uncensored, barons, delle, adaptation, abuses, findings, everson, merrill,
# Nearest to issue: governs, unhelpful, irked, kampuchean, initiations, tensions, chiefly, heist,
# Nearest to egypt: ca, egyptians, calculates, annales, dubai, bonneville, puritanism, beds,
# Nearest to gold: silver, nazionale, estimators, mined, specifier, kneel, rpgs, annually,
# Nearest to pressure: scrape, megaton, remonstrance, exhaust, insulating, damaging, nanometres, eichmann,
# Nearest to something: disembarked, arrogant, he, merits, oz, ve, eyewitnesses, potok,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 4.0028 0.3681 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 4.0016 0.3564 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 4.0016 0.3585 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 4.0317 0.3552 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0230 0.3698 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9713 0.3792 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 4.0039 0.3972 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 4.0157 0.3751 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 4.0106 0.3786 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 3.9973 0.3789 sec/batch
# Nearest to have: prefrontal, closeness, otariidae, living, whois, proportionally, enable, encyclopedic,
# Nearest to between: subdominant, rotates, trance, wherein, nordic, lakeshore, amigaone, broke,
# Nearest to were: catered, had, lamar, frustrated, daemen, chicanos, misalignment, sparta,
# Nearest to this: the, in, exactly, ast, enthusiasms, appendant, mamas, moorland,
# Nearest to so: appalled, barman, elaborates, my, phobias, reasoned, verant, interludes,
# Nearest to but: removing, jscript, communally, efficient, bankrupt, quits, to, time,
# Nearest to i: blackboard, wads, know, asking, wouldn, t, deformations, lighten,
# Nearest to th: rd, margret, colonizing, handwriting, create, reflect, late, heroic,
# Nearest to woman: fertility, female, adult, nurse, guess, frigg, breuer, migrant,
# Nearest to engineering: shusui, manufacturing, coffea, universitet, graduated, tombigbee, macsyma, universities,
# Nearest to dr: uncensored, barons, adaptation, delle, abuses, findings, merrill, everson,
# Nearest to issue: governs, irked, unhelpful, initiations, kampuchean, heist, tensions, darth,
# Nearest to egypt: calculates, egyptians, ca, dubai, annales, puritanism, bonneville, slither,
# Nearest to gold: silver, nazionale, estimators, specifier, kneel, mined, rpgs, annually,
# Nearest to pressure: scrape, megaton, remonstrance, exhaust, eichmann, insulating, damaging, inflow,
# Nearest to something: disembarked, arrogant, he, merits, oz, ve, potok, unknowingly,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 4.0133 0.3796 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9699 0.3720 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9958 0.3682 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 3.9816 0.3823 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 4.0244 0.3715 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 3.9977 0.3794 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9870 0.3799 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9721 0.3685 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9552 0.3618 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.0238 0.3664 sec/batch
# Nearest to have: closeness, prefrontal, proportionally, whois, amerindian, type, otariidae, mennonite,
# Nearest to between: subdominant, trance, rotates, nordic, lakeshore, broke, amigaone, papuan,
# Nearest to were: catered, had, chicanos, misalignment, lamar, daemen, counterbalanced, henares,
# Nearest to this: in, exactly, ast, mamas, enthusiasms, fluorides, received, propagated,
# Nearest to so: appalled, reschedule, elaborates, my, safeguard, barman, reasoned, phobias,
# Nearest to but: communally, removing, efficient, ghazni, time, jscript, ceylon, bankrupt,
# Nearest to i: wads, blackboard, know, asking, wouldn, deformations, t, myself,
# ...
# Epoch 9/10 Iteration: 38600 Avg. Training loss: 3.8751 0.3900 sec/batch
# Epoch 9/10 Iteration: 38700 Avg. Training loss: 3.8540 0.3665 sec/batch
# Epoch 9/10 Iteration: 38800 Avg. Training loss: 3.8448 0.3729 sec/batch
# Epoch 9/10 Iteration: 38900 Avg. Training loss: 3.8859 0.3780 sec/batch
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 3.9159 0.3629 sec/batch
# Nearest to have: are, has, not, to, these, however, most, some,
# Nearest to between: respectively, subdominant, outside, wherein, trance, broke, rotates, double,
# Nearest to were: had, some, most, in, though, developed, catered, many,
# Nearest to this: in, the, to, of, on, a, today, departs,
# Nearest to so: appalled, having, just, why, barman, ensures, interludes, doesn,
# Nearest to but: had, not, time, to, when, did, seems, which,
# Nearest to i: my, myself, know, t, do, we, trapped, wouldn,
# Nearest to th: rd, late, century, nd, bowls, colspan, paced, handwriting,
# Nearest to woman: fertility, her, female, adult, migrant, nurse, women, birth,
# Nearest to engineering: universitet, burlington, unwillingly, samplers, constrained, tombigbee, miramar, hydrodynamics,
# Nearest to dr: uncensored, delle, finnsburg, strange, bayard, stories, bueno, tj,
# Nearest to issue: heist, asser, irked, unhelpful, darth, initiations, tensions, synopsis,
# Nearest to egypt: egyptians, egyptian, dubai, calculates, smoker, amenhotep, bey, sadat,
# Nearest to gold: silver, kneel, estimators, medals, mined, nazionale, specifier, medal,
# Nearest to pressure: exhaust, venturi, evaporation, inflow, ghosh, fluid, impingement, kaye,
# Nearest to something: disembarked, dodgson, ve, ll, flavours, unknowingly, he, clumping,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.8419 0.3816 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8410 0.3737 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8490 0.3915 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8712 0.3644 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8820 0.3653 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8611 0.3819 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8630 0.3778 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8590 0.3761 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8549 0.3956 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8834 0.3742 sec/batch
# Nearest to have: are, has, not, most, there, to, however, these,
# Nearest to between: respectively, subdominant, outside, a, hamilton, double, rotates, broke,
# Nearest to were: in, some, had, though, catered, most, many, chicanos,
# Nearest to this: in, the, of, on, to, a, today, for,
# Nearest to so: appalled, just, why, having, barman, my, ensures, couldn,
# Nearest to but: not, had, when, time, to, did, which, seems,
# Nearest to i: my, myself, know, do, t, wouldn, you, trapped,
# Nearest to th: rd, late, century, handwriting, nd, reflect, colspan, bowls,
# Nearest to woman: fertility, female, her, adult, migrant, women, rate, birth,
# Nearest to engineering: universitet, samplers, unwillingly, burlington, constrained, miramar, tombigbee, hydrodynamics,
# Nearest to dr: uncensored, delle, finnsburg, strange, tadeusz, hardship, trinidad, contrition,
# Nearest to issue: heist, asser, irked, unhelpful, darth, tensions, initiations, marketable,
# Nearest to egypt: egyptians, egyptian, dubai, calculates, amenhotep, smoker, bey, sadat,
# Nearest to gold: silver, mined, kneel, estimators, medals, nazionale, specifier, medal,
# Nearest to pressure: exhaust, venturi, evaporation, ghosh, inflow, remonstrance, fluid, kaye,
# Nearest to something: disembarked, dodgson, flavours, ll, clumping, unknowingly, ve, clippings,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8680 0.3791 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8301 0.3803 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8347 0.3873 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8185 0.3825 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.8952 0.3763 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8551 0.3617 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9465 0.3906 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.8937 0.3774 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.9382 0.3680 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.8387 0.3621 sec/batch
# Nearest to have: are, has, not, most, to, some, there, however,
# Nearest to between: subdominant, respectively, outside, rotates, kambojas, hamilton, colourful, trance,
# Nearest to were: though, in, most, had, some, many, catered, other,
# Nearest to this: in, the, on, of, to, today, for, and,
# Nearest to so: appalled, just, my, why, interludes, ensures, barman, reschedule,
# Nearest to but: not, had, seems, time, when, did, to, jscript,
# Nearest to i: my, myself, know, t, do, wouldn, will, we,
# Nearest to th: rd, century, late, nd, reflect, colspan, handwriting, bowls,
# Nearest to woman: fertility, female, adult, her, migrant, birth, rate, male,
# Nearest to engineering: universitet, burlington, samplers, unwillingly, constrained, miramar, decipherment, hydrodynamics,
# Nearest to dr: uncensored, delle, strange, finnsburg, bueno, eleven, bayard, trinidad,
# Nearest to issue: heist, asser, irked, unhelpful, tensions, star, championships, darth,
# Nearest to egypt: egyptians, dubai, egyptian, calculates, amenhotep, smoker, bey, sadat,
# Nearest to gold: silver, medals, kneel, estimators, mined, nazionale, specifier, olympic,
# Nearest to pressure: exhaust, venturi, evaporation, remonstrance, fluid, impingement, ghosh, inflow,
# Nearest to something: dodgson, disembarked, ve, flavours, ll, clippings, streak, bother,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.7856 0.3619 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8427 0.3738 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.8048 0.3635 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8283 0.4587 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8418 0.3781 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8681 0.3852 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.8646 0.2433 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8484 0.3800 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.8124 0.4009 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8656 0.3760 sec/batch
# Nearest to have: are, not, has, to, most, however, there, had,
# Nearest to between: subdominant, outside, respectively, a, broke, rotates, kambojas, double,
# Nearest to were: in, had, some, though, most, catered, many, other,
# Nearest to this: in, on, the, of, to, a, with, and,
# Nearest to so: appalled, having, just, elaborates, why, rechargeable, ensures, the,
# Nearest to but: had, not, to, when, seems, did, time, was,
# Nearest to i: my, myself, know, do, t, will, wouldn, trapped,
# Nearest to th: rd, late, century, nd, handwriting, reflect, bowls, st,
# Nearest to woman: fertility, female, her, migrant, adult, birth, rate, women,
# Nearest to engineering: universitet, samplers, unwillingly, constrained, burlington, miramar, decipherment, speeded,
# Nearest to dr: uncensored, finnsburg, strange, trinidad, bueno, eleven, delle, tadeusz,
# Nearest to issue: heist, asser, irked, tensions, unhelpful, kampuchean, stipulations, championships,
# Nearest to egypt: egyptians, egyptian, dubai, amenhotep, calculates, smoker, middle, bey,
# Nearest to gold: silver, kneel, medals, estimators, nazionale, olympic, medal, mined,
# Nearest to pressure: exhaust, venturi, impingement, evaporation, fluid, scrape, inflow, blockage,
# Nearest to something: disembarked, dodgson, clumping, flavours, ve, ll, unknowingly, streak,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.8375 0.3702 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.8414 0.3684 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.7933 0.3662 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.8384 0.4274 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8605 0.4511 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8566 0.4545 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8799 0.4473 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7237 0.4550 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.8260 0.4323 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.8051 0.4365 sec/batch
# Nearest to have: are, not, to, has, some, however, most, there,
# Nearest to between: respectively, outside, subdominant, a, double, colourful, broke, wherein,
# Nearest to were: some, most, in, had, though, many, catered, other,
# Nearest to this: in, the, to, on, of, a, and, is,
# Nearest to so: appalled, having, just, my, doesn, rechargeable, why, how,
# Nearest to but: not, had, to, when, seems, time, did, enough,
# Nearest to i: my, myself, know, do, t, we, wouldn, you,
# Nearest to th: rd, late, century, reflect, nd, handwriting, bowls, colspan,
# Nearest to woman: fertility, female, her, migrant, birth, adult, rate, women,
# Nearest to engineering: universitet, unwillingly, burlington, samplers, miramar, constrained, speeded, hogeschool,
# Nearest to dr: uncensored, strange, finnsburg, eleven, delle, bueno, trinidad, portfolios,
# Nearest to issue: heist, asser, kampuchean, unhelpful, tensions, irked, ionizing, marketable,
# Nearest to egypt: egyptians, egyptian, dubai, sadat, smoker, calculates, bey, amenhotep,
# Nearest to gold: silver, kneel, medals, estimators, specifier, mined, nazionale, medal,
# Nearest to pressure: exhaust, venturi, evaporation, impingement, inflow, ghosh, scrape, blockage,
# Nearest to something: dodgson, disembarked, ve, flavours, streak, clumping, ll, roxen,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7797 0.4587 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.8553 0.4351 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8491 0.4282 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.8091 0.4296 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.8494 0.4744 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.9151 0.4638 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.8456 0.4569 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.7892 0.4295 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.8230 0.4319 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8267 0.4345 sec/batch
# Nearest to have: are, not, has, to, some, however, there, most,
# Nearest to between: outside, respectively, subdominant, and, broke, a, with, colourful,
# Nearest to were: had, some, though, in, most, many, been, chicanos,
# Nearest to this: in, the, to, on, of, for, a, and,
# Nearest to so: appalled, having, just, how, why, ensures, my, reschedule,
# Nearest to but: not, had, to, when, time, seems, did, which,
# Nearest to i: my, myself, know, do, t, you, wouldn, we,
# Nearest to th: rd, late, century, nd, handwriting, colspan, reflect, hoff,
# Nearest to woman: fertility, female, her, birth, migrant, adult, women, nurse,
# Nearest to engineering: universitet, unwillingly, miramar, constrained, burlington, samplers, macsyma, speeded,
# Nearest to dr: uncensored, strange, finnsburg, rappers, eleven, delle, trinidad, contrition,
# Nearest to issue: heist, asser, ionizing, darth, tensions, star, polemical, kampuchean,
# Nearest to egypt: egyptians, egyptian, dubai, calculates, sadat, amenhotep, smoker, middle,
# Nearest to gold: silver, medals, kneel, estimators, olympic, nazionale, medal, mined,
# Nearest to pressure: exhaust, venturi, inflow, impingement, conclusions, kaye, evaporation, scrape,
# Nearest to something: dodgson, disembarked, streak, clumping, flavours, ll, feel, opinion,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8509 0.4325 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8607 0.4306 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.8343 0.4303 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.7909 0.4260 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8443 0.4541 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8475 0.4617 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8333 0.4516 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8281 0.4390 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.8137 0.4339 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.8311 0.4351 sec/batch
# Nearest to have: are, not, has, to, however, some, most, there,
# Nearest to between: and, in, outside, respectively, a, with, subdominant, the,
# Nearest to were: some, had, in, though, most, many, been, other,
# Nearest to this: in, the, to, on, of, for, a, many,
# Nearest to so: just, having, reschedule, how, why, ensures, remain, put,
# Nearest to but: not, to, had, when, the, time, and, all,
# Nearest to i: my, myself, know, do, t, will, you, we,
# Nearest to th: rd, late, century, handwriting, nd, reflect, colspan, bowls,
# Nearest to woman: fertility, female, her, birth, migrant, rate, male, nurse,
# Nearest to engineering: universitet, constrained, unwillingly, miramar, burlington, samplers, macsyma, speeded,
# Nearest to dr: uncensored, finnsburg, strange, contrition, hammurabi, delle, eleven, rappers,
# Nearest to issue: heist, asser, kampuchean, star, unhelpful, tensions, stipulations, marketable,
# Nearest to egypt: egyptians, egyptian, dubai, amenhotep, sadat, calculates, smoker, middle,
# Nearest to gold: silver, medals, kneel, olympic, mined, estimators, medal, nazionale,
# Nearest to pressure: exhaust, venturi, inflow, ghosh, remonstrance, evaporation, impingement, kaye,
# Nearest to something: dodgson, disembarked, streak, clumping, ll, flavours, feel, ve,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8432 0.4302 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.8233 0.4528 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.9357 0.5113 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.8851 0.4878 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.9012 0.4734 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.8125 0.4434 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.7943 0.4491 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8237 0.4642 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7818 0.4811 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8454 0.4636 sec/batch
# Nearest to have: are, not, has, some, however, most, to, there,
# Nearest to between: subdominant, respectively, and, broke, a, outside, kambojas, in,
# Nearest to were: some, most, many, though, had, developed, other, been,
# Nearest to this: in, the, on, of, to, for, a, many,
# Nearest to so: just, appalled, my, reschedule, having, why, doesn, barman,
# Nearest to but: not, had, to, when, time, did, which, seems,
# Nearest to i: my, myself, know, do, t, wouldn, will, you,
# Nearest to th: rd, century, late, nd, colspan, reflect, st, handwriting,
# Nearest to woman: fertility, female, birth, male, migrant, her, rate, adult,
# Nearest to engineering: universitet, unwillingly, miramar, constrained, samplers, macsyma, burlington, decipherment,
# Nearest to dr: uncensored, strange, rappers, eleven, contrition, finnsburg, delle, hammurabi,
# Nearest to issue: asser, heist, tensions, kampuchean, polemical, championships, thummim, star,
# Nearest to egypt: egyptians, egyptian, dubai, amenhotep, sadat, calculates, smoker, multivibrator,
# Nearest to gold: silver, medals, kneel, olympic, medal, mined, estimators, specifier,
# Nearest to pressure: exhaust, venturi, impingement, inflow, evaporation, ghosh, conclusions, fluid,
# Nearest to something: dodgson, disembarked, streak, flavours, feel, clumping, ll, camelcase,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8391 0.4574 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.8010 0.4540 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
